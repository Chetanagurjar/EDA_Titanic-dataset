# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max.columns',None)
pd.set_option('display.max.rows',None)

# %% [markdown]
# # Read the  datasets

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#shape of dataset
df.shape
# Out:
# (891, 12)

# %%
#size of dataset
df.size
# Out:
# 10692

# %%
#columns name of dataset
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#description of dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#check missing null values in dataset
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#percentage of null values in whole data
var=df.isnull().mean()*100
var.sum()
# Out:
# 97.19416386083053

# %%
#check duplicate value in dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # check values in each columns:-

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [raw]
# Numerical columns:-[passegerId,Age,Fare]
# Categorical columns:-[Survived,Pclass,sex,SibSp,Parch,Embarked]
# string column:-[Name]
# Mixed column:-[Ticket,Cabin]

# %%
#datatype of columns
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Extract numerical columns from dataset
for i in df.columns:
    if df[i].dtype=='int64' or df[i].dtype=='float64':
        print([i])
print("This are numeric column list:-")
# Out:
# ['PassengerId']
# ['Survived']
# ['Pclass']
# ['Age']
# ['SibSp']
# ['Parch']
# ['Fare']
# This are numeric column list:-

# %%
#Extract not numerical columns from Dataset
for i in df.columns:
    if df[i].dtype=='object':
        print([i])
print("This are not numerical  column list:-")
# Out:
# ['Name']
# ['Sex']
# ['Ticket']
# ['Cabin']
# ['Embarked']
# This are not numerical  column list:-

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df['Ticket'].duplicated().sum()
# Out:
# 210

# %%
df['Ticket'].isnull().sum()
# Out:
# 0

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
v=df[df['Fare']==0]
v.shape
# Out:
# (15, 12)

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
C=df[df['Cabin']==0]
C.shape
# Out:
# (0, 12)

# %%
df['Cabin'].duplicated().sum()
# Out:
# 743

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# # READ TEXT DATASET

# %%
test=pd.read_csv("test.csv")
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#shape of dataset
test.shape
# Out:
# (418, 11)

# %%
#size of dataset
test.size
# Out:
# 4598

# %%
#columns name of dataset
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#information of dataset
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
#description of dataset
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
#check missing null values in dataset
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#check duplicate value in dataset
test.duplicated().sum()
# Out:
# 0

# %%
#datatype of columns
print(test.dtypes)
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#Extract numerical columns from dataset
for i in df.columns:
    if df[i].dtype=='int64' or df[i].dtype=='float64':
        print([i])
print("This are numeric column list:-")
# Out:
# ['PassengerId']
# ['Survived']
# ['Pclass']
# ['Age']
# ['SibSp']
# ['Parch']
# ['Fare']
# This are numeric column list:-

# %%
#Extract not numerical columns from Dataset
for i in df.columns:
    if df[i].dtype=='object':
        print([i])
print("This are not numerical  column list:-")
# Out:
# ['Name']
# ['Sex']
# ['Ticket']
# ['Cabin']
# ['Embarked']
# This are not numerical  column list:-

# %%
test['Pclass'].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
n=test['Name'].unique()
n.shape
# Out:
# (418,)

# %%
test['Age'].isnull().sum()
# Out:
# 86

# %%
test['Ticket'].duplicated().sum()
# Out:
# 55

# %%
t=test[test['Fare']==0]
t.shape
# Out:
# (2, 11)

# %%
test['Cabin'].isnull().sum()
# Out:
# 327

# %%
df[df['Ticket']=="CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df[df['Name'].str.contains("Sage")]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
test[test['Ticket']=="CA. 2343"]
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 188         1080       3                 Sage, Miss. Ada  female   NaN      8
# 342         1234       3           Sage, Mr. John George    male   NaN      1
# 360         1252       3     Sage, Master. William Henry    male  14.5      8
# 365         1257       3  Sage, Mrs. John (Annie Bullen)  female   NaN      1
#
#      Parch    Ticket   Fare Cabin Embarked
# 188      2  CA. 2343  69.55   NaN        S
# 342      9  CA. 2343  69.55   NaN        S
# 360      2  CA. 2343  69.55   NaN        S
# 365      9  CA. 2343  69.55   NaN        S

# %%
#Concatenate the data train ans  test data
train=pd.concat([df,test])
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Add new column is family_size :-
train['family_size']=train['SibSp']+train['Parch']+1
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# ...

# %%
#Add famiy_size_types:-
train['family_type']=np.where(train['family_size']==1,"Alone",
                             np.where(train['family_size']<=4,"Small family",
                             np.where(train['family_size']<=6,"Middle family",
                             np.where(train['family_size']>6,"Large family",train['family_size']
                                     )) ))

# %%
train['Title']=train['Name'].str.split(',').str[1].str.split('.').str[0]
train['Title'].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Master', ' Don', ' Rev', ' Dr', ' Mme',
#        ' Ms', ' Major', ' Lady', ' Sir', ' Mlle', ' Col', ' Capt',
#        ' the Countess', ' Jonkheer', ' Dona'], dtype=object)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# 5              6       0.0       3
# 6              7       0.0       1
# 7              8       0.0       3
# 8              9       1.0       3
# 9             10       1.0       2
# 10            11       1.0       3
# 11            12       1.0       1
# 12            13       0.0       3
# 13            14       0.0       3
# 14            15       0.0       3
# 15            16       1.0       2
# 16            17       0.0       3
# 17            18       1.0       2
# 18            19       0.0       3
# 19            20       1.0       3
# 20            21       0.0       2
# 21            22       1.0       2
# 22            23       1.0       3
# 23            24       1.0       1
# 24            25       0.0       3
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# **univariate Analysis for numerical columns**

# %%
#Age column analysis

# %%
train['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1309 entries, 0 to 417
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 1046 non-null   float64
# dtypes: float64(1)
# memory usage: 20.5 KB

# %%
#description of age col:-
train['Age'].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
#count
train['Age'].shape
# Out:
# (1309,)

# %%
#null values
train['Age'].isnull().sum()
# Out:
# 263

# %%
#percentage of missing values
(train['Age'].isnull().sum()/len(train['Age']))*100
# Out:
# 20.091673032849503

# %%
#calculation
print("Median of Age is:-",train['Age'].median())
print("Mean of Age is:-",round(train['Age'].mean(),2))
print("Mode of Age is:-",train['Age'].mode())
print("Std of Age is:-",round(train['Age'].std(),2))
print("variance of Age is:-",round(train['Age'].var(),2))
# Out:
# Median of Age is:- 28.0
# Mean of Age is:- 29.88
# Mode of Age is:- 0    24.0
# Name: Age, dtype: float64
# Std of Age is:- 14.41
# variance of Age is:- 207.75

# %%
 #Distribution of Age columns
sns.distplot(train['Age'])
# Out:
# C:\Users\Chetana\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.hist(train['Age'],bins=10)
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(train['Age'])
# Out:
# C:\Users\Chetana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
train['Age'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
train['Age'].skew()    #perfect skewness
# Out:
# 0.40767455974362266

# %%
train['Age'].kurt()     #normal distribution
# Out:
# 0.1469476357378139

# %%
#Fare column

# %%
train['Fare'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1309 entries, 0 to 417
# Series name: Fare
# Non-Null Count  Dtype
# --------------  -----
# 1308 non-null   float64
# dtypes: float64(1)
# memory usage: 20.5 KB

# %%
#discription:-
train['Fare'].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %%
#count
train['Age'].shape
# Out:
# (1309,)

# %%
#null value
train['Fare'].isnull().sum()
# Out:
# 1

# %%
#percentage of missing value:
(train['Fare'].isnull().sum()/len(train['Fare']))*100
# Out:
# 0.07639419404125286

# %%
#calculation
print("Median of Age is:-",train['Fare'].median())
print("Mean of Age is:-",round(train['Fare'].mean(),2))
print("Mode of Age is:-",train['Fare'].mode())
print("Std of Age is:-",round(train['Fare'].std(),2))
print("variance of Age is:-",round(train['Age'].var(),2))
# Out:
# Median of Age is:- 14.4542
# Mean of Age is:- 33.3
# Mode of Age is:- 0    8.05
# Name: Fare, dtype: float64
# Std of Age is:- 51.76
# variance of Age is:- 207.75

# %%
#check skewness
train['Fare'].skew()        #positive skewed
# Out:
# 4.367709134122922

# %%
#Distribution of Fare columns
sns.distplot(train['Fare'])
# Out:
# C:\Users\Chetana\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
train['Fare'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(train['Fare'])
# Out:
# C:\Users\Chetana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# **univariate Analysis for Categorical columns**

# %%
#Survived column analysis

# %%
#count of passenger survived and not survived(0=death,1=survived)
train['Survived'].value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
#null values
train['Survived'].isnull().sum()
# Out:
# 418

# %%
#percentage of missing values:-
(train['Survived'].isnull().sum()/len(train['Survived']))*100
# Out:
# 31.932773109243694

# %%
#distribution by charts:-
train['Survived'].value_counts().plot(kind='pie',autopct="%1.0f%%")
plt.title("Pie Chart of Survived passengers")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Survived passengers')

# %%
#barplot :-
train['Survived'].value_counts().plot(kind='bar')
plt.title("Bar Chart of Survived passengers")
# Out:
# Text(0.5, 1.0, 'Bar Chart of Survived passengers')

# %%
#Pclass column analysis

# %%
#count of passenger Pclass categories(1,2,3)
train['Pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
#null values
train['Pclass'].isnull().sum()
# Out:
# 0

# %%
#distribution by charts:-
train['Pclass'].value_counts().plot(kind='pie',autopct="%1.0f%%")
plt.title("Pie Chart of Pclass passengers")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Pclass passengers')

# %%
train['Pclass'].value_counts().plot(kind='bar')
plt.title("Bar Chart of Pclass passengers")
# Out:
# Text(0.5, 1.0, 'Bar Chart of Pclass passengers')

# %%
#Sex column analysis

# %%
#count of passenger Gende categories(
train['Sex'].value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
#null values:
train['Sex'].isnull().sum()/len(train['Sex'])
# Out:
# 0.0

# %%
#distribution by charts:-
train['Sex'].value_counts().plot(kind='pie',autopct="%1.0f%%")
plt.title("Pie Chart of Sex passengers")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Sex passengers')

# %%
train['Sex'].value_counts().plot(kind='bar')
plt.title("Bar Chart of Gender passengers")
# Out:
# Text(0.5, 1.0, 'Bar Chart of Gender passengers')

# %%
#Embarked columns analysis:-

# %%
#counts the values of embarked category:-
train['Embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
#null vlaues:-
train['Embarked'].isnull().sum()
# Out:
# 2

# %%
##distribution by charts:-
train['Embarked'].value_counts().plot(kind='pie',autopct="%1.0f%%")
plt.title("Pie Chart of Embarked passengers")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Embarked passengers')

# %%
train['Embarked'].value_counts().plot(kind='bar')
plt.title("Bar Chart of Embarked passengers")
# Out:
# Text(0.5, 1.0, 'Bar Chart of Embarked passengers')
